# %% [markdown]
# # Census Planning Database
#
# DOwnload and save to parquet the 2022 ( or the closest year ) census planning database. Include in this notebook the link to the documentation for the databse. I need it for tracts, and we need the tract GEOIDs in FIPS format, without the '140US' etc in the front.
#
#
# 2022 CPDB docs https://www2.census.gov/adrm/PDB/2022/2022_Tract_PDB_Documentation.pdf
