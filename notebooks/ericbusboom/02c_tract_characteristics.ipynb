# %% [markdown]
# # Census Tract Characteristics (Urban/Rural, Metro, Commute)
#
# This notebook retrieves tract-level characteristics from the Census APIs, including 2020 decennial urban/rural counts and 2022 ACS 5-year commute statistics, then saves the merged dataset to `data_dir` for downstream analysis.

# %%
# Enable autoreload and import configuration
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import geopandas as gpd
import numpy as np
import requests
import geopandas as gpd

# Placeholder for linters; actual value defined via config
data_dir = None
# %run ../../config.py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Project root: /Users/eric/proj/scratch/WirelessIncome
# Data directory: /Users/eric/proj/scratch/WirelessIncome/data

# %%
chara_url = "https://ers.usda.gov/sites/default/files/_laserfiche/DataFiles/53241/RUCA-codes-2020-tract.csv"

# USDA encodes this file as Latin-1, so specify the encoding to avoid decode errors.
df = pd.read_csv(chara_url, encoding="latin-1", dtype=str, low_memory=False)
print(f"Loaded {len(df):,} rows from RUCA file")
df.head()
# Out:
# Loaded 85,528 rows from RUCA file
#    TractFIPS23 CountyFIPS23 CountyCode23    CountyName23  TractFIPS20  \
# 0  01001020100        01001          001  Autauga County  01001020100
# 1  01001020200        01001          001  Autauga County  01001020200
# 2  01001020300        01001          001  Autauga County  01001020300
# 3  01001020400        01001          001  Autauga County  01001020400
# 4  01001020501        01001          001  Autauga County  01001020501
#
#   TractCode20          TractName20 CountyFIPS20 CountyCode20    CountyName20  \
# 0      020100     Census Tract 201        01001          001  Autauga County
# 1      020200     Census Tract 202        01001          001  Autauga County
# 2      020300     Census Tract 203        01001          001  Autauga County
# 3      020400     Census Tract 204        01001          001  Autauga County
# 4      020501  Census Tract 205.01        01001          001  Autauga County
#
#    ... PrimaryRUCADescription PrimaryDestinationCode PrimaryDestinationName  \
# 0  ...      Metropolitan core                  58600         Montgomery, AL
# 1  ...      Metropolitan core                  58600         Montgomery, AL
# 2  ...      Metropolitan core                  58600         Montgomery, AL
# 3  ...      Metropolitan core                  58600         Montgomery, AL
# 4  ...      Metropolitan core                  58600         Montgomery, AL
#
#   SecondaryRUCA              SecondaryRUCADescription  \
# 0             1  Metropolitan core, no addtional code
# 1             1  Metropolitan core, no addtional code
# 2             1  Metropolitan core, no addtional code
# 3             1  Metropolitan core, no addtional code
# 4             1  Metropolitan core, no addtional code
#
#   SecondaryDestinationCode                        SecondaryDestinationName  \
# 0               1101005904  Census Tract 59.04; Montgomery County; Alabama
# 1               1101005904  Census Tract 59.04; Montgomery County; Alabama
# 2               1101005904  Census Tract 59.04; Montgomery County; Alabama
# 3               1101005904  Census Tract 59.04; Montgomery County; Alabama
# 4               1101005904  Census Tract 59.04; Montgomery County; Alabama
#
#   Population LandArea PopDensity
# 0       1775      3.8      467.9
# 1       2055      1.3     1602.7
# 2       3216      2.1     1557.1
# 3       4246      2.5     1722.5
# 4       4322      2.4     1804.4
#
# [5 rows x 27 columns]

# %%
tracts_url = "https://www2.census.gov/geo/tiger/GENZ2022/shp/cb_2022_us_tract_500k.zip"
tracts_gdf = gpd.read_file(tracts_url)
tracts_gdf = tracts_gdf[["GEOID", "NAME", "STATEFP", "COUNTYFP", "TRACTCE"]]
print(f"Loaded {len(tracts_gdf):,} tract geometries from 2022 TIGER/Line")

tract_cols = [col for col in ["TractFIPS23", "TractFIPS20", "TractFIPS"] if col in df.columns]
if not tract_cols:
    raise ValueError("RUCA file is missing expected TractFIPS columns")

link_checks = []
geoids = set(tracts_gdf["GEOID"].astype(str))
for col in tract_cols:
    values = df[col].astype(str).str.strip().str.zfill(11)
    df[col + "_normalized"] = values
    matches = values.isin(geoids)
    link_checks.append(
        {
            "column": col,
            "count": len(values),
            "matches": matches.sum(),
            "match_pct": matches.mean(),
        }
    )

link_df = pd.DataFrame(link_checks)
print("TractFIPS linkage quality vs GEOID:")
link_df
# Out:
# Loaded 85,185 tract geometries from 2022 TIGER/Line
# TractFIPS linkage quality vs GEOID:
#         column  count  matches  match_pct
# 0  TractFIPS23  85528    85185   0.995990
# 1  TractFIPS20  85528    84306   0.985712

# %%
df.head().T
# Out:
#                                                                        0  \
# TractFIPS23                                                  01001020100
# CountyFIPS23                                                       01001
# CountyCode23                                                         001
# CountyName23                                              Autauga County
# TractFIPS20                                                  01001020100
# TractCode20                                                       020100
# TractName20                                             Census Tract 201
# CountyFIPS20                                                       01001
# CountyCode20                                                         001
# CountyName20                                              Autauga County
# StateFIPS20                                                           01
# StateName20                                                      Alabama
# UrbanAreaCode20                                                    58600
# UrbanAreaName20                                           Montgomery, AL
# UrbanCore                                                              1
# UrbanCoreType                                                 Metro core
# PrimaryRUCA                                                            1
# PrimaryRUCADescription                                 Metropolitan core
# PrimaryDestinationCode                                             58600
# PrimaryDestinationName                                    Montgomery, AL
# SecondaryRUCA                                                          1
# SecondaryRUCADescription            Metropolitan core, no addtional code
# SecondaryDestinationCode                                      1101005904
# SecondaryDestinationName  Census Tract 59.04; Montgomery County; Alabama
# Population                                                          1775
# LandArea                                                             3.8
# PopDensity                                                         467.9
# TractFIPS23_normalized                                       01001020100
# TractFIPS20_normalized                                       01001020100
#
#                                                                        1  \
# TractFIPS23                                                  01001020200
# CountyFIPS23                                                       01001
# CountyCode23                                                         001
# CountyName23                                              Autauga County
# TractFIPS20                                                  01001020200
# TractCode20                                                       020200
# TractName20                                             Census Tract 202
# CountyFIPS20                                                       01001
# CountyCode20                                                         001
# CountyName20                                              Autauga County
# StateFIPS20                                                           01
# StateName20                                                      Alabama
# UrbanAreaCode20                                                    58600
# UrbanAreaName20                                           Montgomery, AL
# UrbanCore                                                              1
# UrbanCoreType                                                 Metro core
# PrimaryRUCA                                                            1
# PrimaryRUCADescription                                 Metropolitan core
# PrimaryDestinationCode                                             58600
# PrimaryDestinationName                                    Montgomery, AL
# SecondaryRUCA                                                          1
# SecondaryRUCADescription            Metropolitan core, no addtional code
# SecondaryDestinationCode                                      1101005904
# SecondaryDestinationName  Census Tract 59.04; Montgomery County; Alabama
# Population                                                          2055
# LandArea                                                             1.3
# PopDensity                                                        1602.7
# TractFIPS23_normalized                                       01001020200
# TractFIPS20_normalized                                       01001020200
#
#                                                                        2  \
# TractFIPS23                                                  01001020300
# CountyFIPS23                                                       01001
# CountyCode23                                                         001
# CountyName23                                              Autauga County
# TractFIPS20                                                  01001020300
# TractCode20                                                       020300
# TractName20                                             Census Tract 203
# CountyFIPS20                                                       01001
# CountyCode20                                                         001
# CountyName20                                              Autauga County
# StateFIPS20                                                           01
# StateName20                                                      Alabama
# UrbanAreaCode20                                                    58600
# UrbanAreaName20                                           Montgomery, AL
# UrbanCore                                                              1
# UrbanCoreType                                                 Metro core
# PrimaryRUCA                                                            1
# PrimaryRUCADescription                                 Metropolitan core
# PrimaryDestinationCode                                             58600
# PrimaryDestinationName                                    Montgomery, AL
# SecondaryRUCA                                                          1
# SecondaryRUCADescription            Metropolitan core, no addtional code
# SecondaryDestinationCode                                      1101005904
# SecondaryDestinationName  Census Tract 59.04; Montgomery County; Alabama
# Population                                                          3216
# LandArea                                                             2.1
# PopDensity                                                        1557.1
# TractFIPS23_normalized                                       01001020300
# TractFIPS20_normalized                                       01001020300
#
#                                                                        3  \
# TractFIPS23                                                  01001020400
# CountyFIPS23                                                       01001
# CountyCode23                                                         001
# CountyName23                                              Autauga County
# TractFIPS20                                                  01001020400
# TractCode20                                                       020400
# TractName20                                             Census Tract 204
# CountyFIPS20                                                       01001
# CountyCode20                                                         001
# CountyName20                                              Autauga County
# StateFIPS20                                                           01
# StateName20                                                      Alabama
# UrbanAreaCode20                                                    58600
# UrbanAreaName20                                           Montgomery, AL
# UrbanCore                                                              1
# UrbanCoreType                                                 Metro core
# PrimaryRUCA                                                            1
# PrimaryRUCADescription                                 Metropolitan core
# PrimaryDestinationCode                                             58600
# PrimaryDestinationName                                    Montgomery, AL
# SecondaryRUCA                                                          1
# SecondaryRUCADescription            Metropolitan core, no addtional code
# SecondaryDestinationCode                                      1101005904
# SecondaryDestinationName  Census Tract 59.04; Montgomery County; Alabama
# Population                                                          4246
# LandArea                                                             2.5
# PopDensity                                                        1722.5
# TractFIPS23_normalized                                       01001020400
# TractFIPS20_normalized                                       01001020400
#
#                                                                        4
# TractFIPS23                                                  01001020501
# CountyFIPS23                                                       01001
# CountyCode23                                                         001
# CountyName23                                              Autauga County
# TractFIPS20                                                  01001020501
# TractCode20                                                       020501
# TractName20                                          Census Tract 205.01
# CountyFIPS20                                                       01001
# CountyCode20                                                         001
# CountyName20                                              Autauga County
# StateFIPS20                                                           01
# StateName20                                                      Alabama
# UrbanAreaCode20                                                    58600
# UrbanAreaName20                                           Montgomery, AL
# UrbanCore                                                              1
# UrbanCoreType                                                 Metro core
# PrimaryRUCA                                                            1
# PrimaryRUCADescription                                 Metropolitan core
# PrimaryDestinationCode                                             58600
# PrimaryDestinationName                                    Montgomery, AL
# SecondaryRUCA                                                          1
# SecondaryRUCADescription            Metropolitan core, no addtional code
# SecondaryDestinationCode                                      1101005904
# SecondaryDestinationName  Census Tract 59.04; Montgomery County; Alabama
# Population                                                          4322
# LandArea                                                             2.4
# PopDensity                                                        1804.4
# TractFIPS23_normalized                                       01001020501
# TractFIPS20_normalized                                       01001020501

# %%
df.UrbanCore.value_counts()
# Out:
# UrbanCore
# 1    66793
# 0    18735
# Name: count, dtype: int64

# %%
# Reduce columns and rename to shorter, lowercase names with underscores
df = df[[
    "TractFIPS23",
    "CountyName20",
    "UrbanCoreType",
    "PrimaryRUCADescription",
    "PrimaryDestinationCode",
    "PopDensity"
]].rename(columns={
    "TractFIPS23": "GEOID",
    "CountyName20": "county_name",
    "UrbanCoreType": "urban_core_type",
    "PrimaryRUCADescription": "primary_ruca_desc",
    "PrimaryDestinationCode": "primary_dest_code",
    "PopDensity": "pop_density"
})

print(f"Reduced to {len(df.columns)} columns: {list(df.columns)}")
df.head()
# Out:
# Reduced to 6 columns: ['GEOID', 'county_name', 'urban_core_type', 'primary_ruca_desc', 'primary_dest_code', 'pop_density']
#          GEOID     county_name urban_core_type  primary_ruca_desc  \
# 0  01001020100  Autauga County      Metro core  Metropolitan core
# 1  01001020200  Autauga County      Metro core  Metropolitan core
# 2  01001020300  Autauga County      Metro core  Metropolitan core
# 3  01001020400  Autauga County      Metro core  Metropolitan core
# 4  01001020501  Autauga County      Metro core  Metropolitan core
#
#   primary_dest_code pop_density
# 0             58600       467.9
# 1             58600      1602.7
# 2             58600      1557.1
# 3             58600      1722.5
# 4             58600      1804.4

# %%
output_path = data_dir / "tract_characteristics.parquet"
df.to_parquet(output_path, index=False)
print(f"Saved {len(df):,} tract characteristics to {output_path}")
# Out:
# Saved 85,528 tract characteristics to /Users/eric/proj/scratch/WirelessIncome/data/tract_characteristics.parquet
