# %% [markdown]
# prompt:  load the parquet fies we created in the other two notebooks and perform
# a regression to analyze the relationship between median income of a tract
# (independent variable ) and the average download speeds (dependent variable ) in
# that tract. You will need to do a spatial join on the two dataset, to locate
# each point from the uss_mobile_2022q1 dataset to a census tract, then aggregate
# by tract, computing the average or median download speed or upload speed. You
# should create an analysis function to parameterize which statistic of central
# tendencay we use, and which dependent variable we use. Use statsmodel for the OLS.
#
# ## Updates
#
# [ When you have completed an update, put `[DONE]` in front of it, after the bullet. ]
#
# * [DONE] You do not need to create Points from tile_x and til_y in the uss_mobile dataset, there is already a geometry field. You might have to use shapely.loads to convert that from a string to a geometry, but check first.
#
# * [DONE] Aggregating the joined dataset:  average these fields: ['avg_d_kbps',
#   'avg_u_kbps', 'avg_lat_ms', 'avg_lat_down_ms', 'avg_lat_up_ms']. sum these
#   fields: ['tests', 'devices']. group by: 'GEOID'. There should be only one
#   'median_income', and it should be passed through.

# %%
 # Enable autoreload and import libraries
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import geopandas as gpd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# Load configuration
data_dir = None
# %run ../../../config.py
# Out:
# Project root: /Users/eric/proj/scratch/WirelessIncome
# Data directory: /Users/eric/proj/scratch/WirelessIncome/data

# %%
df = pd.read_parquet(data_dir/'merged_2022.parquet')
df.head()
# Out:
#          GEOID  avg_d_kbps_fixed  avg_d_kbps_mobile  tests_fixed  \
# 0  01001020100     198218.097274       73227.430357        513.0
# 1  01001020200     229213.872727       40949.616667        304.0
# 2  01001020300     243372.740896      128294.737500        375.0
# 3  01001020400     199444.351471      120218.070833        649.0
# 4  01001020501     240464.220486       96485.661310        954.0
#
#    tests_mobile                                          NAME  population  \
# 0          35.0     Census Tract 201; Autauga County; Alabama        1865
# 1          25.0     Census Tract 202; Autauga County; Alabama        1861
# 2          67.0     Census Tract 203; Autauga County; Alabama        3492
# 3          40.0     Census Tract 204; Autauga County; Alabama        3987
# 4          60.0  Census Tract 205.01; Autauga County; Alabama        4121
#
#    acs_year state county   tract  median_income STUSPS     county_name  \
# 0      2022    01    001  020100        60563.0     AL  Autauga County
# 1      2022    01    001  020200        57460.0     AL  Autauga County
# 2      2022    01    001  020300        77371.0     AL  Autauga County
# 3      2022    01    001  020400        73191.0     AL  Autauga County
# 4      2022    01    001  020501        79953.0     AL  Autauga County
#
#   urban_core_type  primary_ruca_desc primary_dest_code pop_density
# 0      Metro core  Metropolitan core             58600       467.9
# 1      Metro core  Metropolitan core             58600      1602.7
# 2      Metro core  Metropolitan core             58600      1557.1
# 3      Metro core  Metropolitan core             58600      1722.5
# 4      Metro core  Metropolitan core             58600      1804.4

# %%
df.avg_d_kbps_mobile = df.avg_d_kbps_mobile.clip(0,1e6)
df.avg_d_kbps_fixed = df.avg_d_kbps_fixed.clip(0, 1e6)

# %%
fig, ax = plt.subplots(figsize=(9, 5))
df['avg_d_kbps_mobile'].hist(bins=100, alpha=0.6, label='Mobile download speed', ax=ax)
df['avg_d_kbps_fixed'].hist(bins=100, alpha=0.6, label='Fixed download speed', ax=ax)
ax.set_xlabel('Average download speed (kbps)')
ax.set_ylabel('Tract count')
ax.set_title('Distribution of tract download speeds (2022)')
ax.legend()
plt.tight_layout()

# %%
x_var = "median_income"
y_var = "avg_d_kbps_mobile"

t = df.copy()

X = sm.add_constant(t[x_var])  # add intercept

y = t[y_var]

model = sm.OLS(y, X, missing="drop").fit()

print(model.summary())

# Quick scatter plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(t[x_var], t[y_var], s=4, alpha=0.5)
ax.set_xlabel("Median Household Income (USD)")
ax.set_ylabel("Avg Download Speed (kbps)")
ax.set_title("Income vs Download Speed by Tract (2022 Q1)")
plt.tight_layout()
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_d_kbps_mobile   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     537.7
# Date:                Mon, 08 Dec 2025   Prob (F-statistic):          1.44e-118
# Time:                        18:57:00   Log-Likelihood:            -1.0559e+06
# No. Observations:               82193   AIC:                         2.112e+06
# Df Residuals:                   82191   BIC:                         2.112e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           1.13e+05    722.675    156.398      0.000    1.12e+05    1.14e+05
# median_income     0.1876      0.008     23.188      0.000       0.172       0.204
# ==============================================================================
# Omnibus:                    51599.842   Durbin-Watson:                   0.944
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           894474.328
# Skew:                           2.743   Prob(JB):                         0.00
# Kurtosis:                      18.201   Cond. No.                     2.01e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.01e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x_var = "median_income"
y_var = "avg_d_kbps_fixed"

t = df.copy()
t = t[t.avg_d_kbps_fixed < 10_000_000]

X = sm.add_constant(t[x_var])  # add intercept

y = t[y_var]

model = sm.OLS(y, X, missing="drop").fit()

print(model.summary())

# Quick scatter plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.scatter(t[x_var], t[y_var], s=4, alpha=0.5)
ax.set_xlabel("Median Household Income (USD)")
ax.set_ylabel("Avg Download Speed (kbps)")
ax.set_title("Income vs Fixed Download Speed by Tract (2022)")
plt.tight_layout()
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       avg_d_kbps_fixed   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     3350.
# Date:                Mon, 08 Dec 2025   Prob (F-statistic):               0.00
# Time:                        19:03:21   Log-Likelihood:            -1.0245e+06
# No. Observations:               82249   AIC:                         2.049e+06
# Df Residuals:                   82247   BIC:                         2.049e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          1.766e+05    488.322    361.679      0.000    1.76e+05    1.78e+05
# median_income     0.3166      0.005     57.878      0.000       0.306       0.327
# ==============================================================================
# Omnibus:                     6460.899   Durbin-Watson:                   0.720
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8145.097
# Skew:                          -0.729   Prob(JB):                         0.00
# Kurtosis:                       3.500   Cond. No.                     2.01e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.01e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x_var = "median_income"
y_var = "avg_d_kbps_fixed"

t = df.copy()

# Create color map for urban_core_type
urban_types = t['urban_core_type'].unique()
colors = plt.cm.tab10(range(len(urban_types)))
color_map = dict(zip(urban_types, colors))

# Quick scatter plot
fig, ax = plt.subplots(figsize=(10, 6))
for urban_type in urban_types:
    mask = t['urban_core_type'] == urban_type
    ax.scatter(t[mask][x_var], t[mask][y_var], 
               s=4, alpha=0.5, label=urban_type, color=color_map[urban_type])

ax.set_xlabel("Median Household Income (USD)")
ax.set_ylabel("Avg Download Speed (kbps)")
ax.set_title("Income vs Fixed Download Speed by Tract (2022)")
ax.legend(markerscale=3, loc='best')
plt.tight_layout()
plt.show()

# %%
x_var = "median_income"
y_var = "avg_d_kbps_mobile"

t = df.copy()

# Create color map for urban_core_type
urban_types = t["urban_core_type"].unique()
colors = plt.cm.tab10(range(len(urban_types)))
color_map = dict(zip(urban_types, colors))

# Quick scatter plot
fig, ax = plt.subplots(figsize=(10, 6))
for urban_type in urban_types:
    mask = t["urban_core_type"] == urban_type
    ax.scatter(
        t[mask][x_var],
        t[mask][y_var],
        s=4,
        alpha=0.5,
        label=urban_type,
        color=color_map[urban_type],
    )

ax.set_xlabel("Median Household Income (USD)")
ax.set_ylabel("Avg Download Speed (kbps)")
ax.set_title("Income vs Mobile Download Speed by Tract (2022)")
ax.legend(markerscale=3, loc="best")
plt.tight_layout()
plt.show()

# %%
(df.groupby("urban_core_type").avg_d_kbps_fixed.describe()/1000).round().astype(int)
# Out:
#                  count  mean  std  min  25%  50%  75%  max
# urban_core_type
# Metro core          57   227   41    3  204  229  253  673
# Micro core           5   192   51   17  162  196  226  398
# Rural               18   130   68    5   72  127  183  405
# Small town core      2   166   56   12  132  170  204  398

# %%
(df.groupby("urban_core_type").median_income.describe() / 1000).round().astype(int)
# Out:
#                  count  mean  std  min  25%  50%  75%  max
# urban_core_type
# Metro core          57    85   43    2   55   77  107  250
# Micro core           5    63   27    9   45   58   75  230
# Rural               18    71   26   11   54   66   82  250
# Small town core      2    60   23   10   45   56   71  230

# %%
import pandas as pd

url = "https://www.ooma.com/blog/average-us-internet-speeds-over-time/"
tables = pd.read_html(url)

# The "Average U.S. internet speeds by year" table is the last one on the page
# Headers are in row 1, data starts at row 3
t = tables[-1]
t.columns = t.iloc[0]  # Set row 1 as headers
t = t.iloc[2:].reset_index(drop=True)  # Data starts at row 3

# Convert speed columns to numeric, handling Kb/s and Mb/s suffixes
def parse_speed(speed_str):
    """Convert speed string with Kb/s or Mb/s suffix to numeric kbps"""
    if pd.isna(speed_str):
        return None
    speed_str = str(speed_str).strip()
    if 'Mb/s' in speed_str:
        return float(speed_str.replace('Mb/s', '').strip()) * 1000  # Convert Mb/s to Kb/s
    elif 'Kb/s' in speed_str:
        return float(speed_str.replace('Kb/s', '').strip())
    else:
        return float(speed_str)

# Apply conversion to speed columns (assuming columns are named like 'Download' and 'Upload')
for col in t.columns:
    if col != 'Year' and col is not None:
        t[col] = t[col].apply(parse_speed)

print(t)
# Out:
# 0   Year     Speed
# 0   1993      14.4
# 1   1994      24.0
# 2   1995      27.5
# 3   1996      33.6
# 4   1997      34.3
# 5   1998      44.3
# 6   1999      56.0
# 7   2000     127.0
# 8   2001     200.0
# 9   2002     400.0
# 10  2003     800.0
# 11  2004     861.0
# 12  2005    1100.0
# 13  2006    1550.0
# 14  2007    3500.0
# 15  2008    5580.0
# 16  2009    7120.0
# 17  2010   10000.0
# 18  2011   10000.0
# 19  2012   15000.0
# 20  2013   15600.0
# 21  2014   31000.0
# 22  2015   32000.0
# 23  2016   39000.0
# 24  2017   30740.0
# 25  2018   43390.0
# 26  2019   54080.0
# 27  2020   89830.0
# 28  2021   99920.0
# 29  2022  129420.0
# 30  2023  138900.0
# 31  2024  209000.0
# 32  2025  214000.0

# %%
df.columns
# Out:
# Index(['GEOID', 'avg_d_kbps_fixed', 'avg_d_kbps_mobile', 'tests_fixed',
#        'tests_mobile', 'NAME', 'population', 'acs_year', 'state', 'county',
#        'tract', 'median_income', 'STUSPS', 'county_name', 'urban_core_type',
#        'primary_ruca_desc', 'primary_dest_code', 'pop_density'],
#       dtype='object')

# %%
speed_cols = [c for c in t.columns if c and c != 'Year']
plot_df = t.copy()
plot_df['Year'] = pd.to_numeric(plot_df['Year'], errors='coerce')
plot_df = plot_df.dropna(subset=['Year'])
plot_df = plot_df.set_index('Year')
plot_df_kbps = plot_df[speed_cols].apply(pd.to_numeric, errors='coerce')
plot_df_mbps = plot_df_kbps / 1000
ax = plot_df_mbps.plot(figsize=(9, 5))
ax.set_xlabel('Year')
ax.set_ylabel('Speed (Mbps)')
ax.set_title('Average U.S. internet speeds over time (Ooma)')
plt.tight_layout()

# %%
# Bar chart with error bars for fixed broadband speed by urban core type
fig, ax = plt.subplots(figsize=(10, 6))

# Calculate mean and standard deviation for each urban core type
urban_stats = df.groupby("urban_core_type")["avg_d_kbps_fixed"].agg(
    ["mean", "std", "count"]
)
urban_stats = urban_stats.sort_values("mean", ascending=False)

# Convert to Mbps for readability
urban_stats["mean_mbps"] = urban_stats["mean"] / 1000
urban_stats["std_mbps"] = urban_stats["std"] / 1000

# Create bar chart
bars = ax.bar(
    range(len(urban_stats)),
    urban_stats["mean_mbps"],
    yerr=urban_stats["std_mbps"],
    capsize=5,
    alpha=0.7,
)

# Customize
ax.set_xticks(range(len(urban_stats)))
ax.set_xticklabels(urban_stats.index, rotation=45, ha="right")
ax.set_ylabel("Average Download Speed (Mbps)")
ax.set_xlabel("Urban Core Type")
ax.set_title(
    "Fixed Broadband Download Speed by Urban/Rural Classification\n(Error bars show ±1 standard deviation)"
)
ax.grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# Display the statistics
print("Statistics by urban core type:")
print(urban_stats[["mean_mbps", "std_mbps", "count"]].round(2))
# Out:
# Statistics by urban core type:
#                  mean_mbps  std_mbps  count
# urban_core_type
# Metro core          226.70     41.45  56997
# Micro core          192.32     50.88   5350
# Small town core     166.08     55.54   1980
# Rural               130.06     67.57  17922

# %% [markdown]
# # OLS Regression: Fixed Broadband Speed vs Income and Urban Core Type
#
# Analyze how median income and urban core type (categorical variable) affect fixed broadband download speeds.

# %%
# OLS Regression: avg_d_kbps_fixed ~ median_income + urban_core_type
import statsmodels.formula.api as smf
import pandas as pd
from scipy.stats import zscore
import numpy as np

# Prepare data - drop missing values and ensure proper types
t = df.copy()
t = t.dropna()

# Ensure numeric columns are float
t['avg_d_kbps_fixed'] = pd.to_numeric(t['avg_d_kbps_fixed'], errors='coerce')
t['median_income'] = pd.to_numeric(t['median_income'], errors='coerce')
t["median_income"] = np.log(t["median_income"])

# Standardize income to Z scores using scipy
t["median_income"] = zscore(t["median_income"], nan_policy='omit')
t["pop_density"] = zscore(pd.to_numeric(t["pop_density"]), nan_policy="omit")

# Drop any rows that became NaN after conversion
t = t.dropna()

model = smf.ols(
    "avg_d_kbps_fixed ~ median_income + pop_density + C(urban_core_type) + C(county)",
    data=t,
).fit(cov_type="HC3")

# Display results
print(model.summary())
print(f"\nNumber of observations: {len(t):,}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       avg_d_kbps_fixed   R-squared:                       0.460
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     428.5
# Date:                Mon, 08 Dec 2025   Prob (F-statistic):               0.00
# Time:                        18:57:12   Log-Likelihood:            -9.8827e+05
# No. Observations:               81291   AIC:                         1.977e+06
# Df Residuals:                   80976   BIC:                         1.980e+06
# Df Model:                         314
# Covariance Type:                  HC3
# =========================================================================================================
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                              2.207e+05   1095.160    201.555      0.000    2.19e+05    2.23e+05
# C(urban_core_type)[T.Micro core]      -2.703e+04    733.155    -36.872      0.000   -2.85e+04   -2.56e+04
# C(urban_core_type)[T.Rural]           -8.944e+04    561.878   -159.175      0.000   -9.05e+04   -8.83e+04
# C(urban_core_type)[T.Small town core] -5.034e+04   1269.647    -39.651      0.000   -5.28e+04   -4.79e+04
# C(county)[T.003]                       6004.3970   1445.463      4.154      0.000    3171.341    8837.453
# C(county)[T.005]                       1.335e+04   1658.245      8.053      0.000    1.01e+04    1.66e+04
# C(county)[T.006]                      -2.035e+04   1.76e+04     -1.158      0.247   -5.48e+04    1.41e+04
# C(county)[T.007]                       1.316e+04   2187.420      6.014      0.000    8868.016    1.74e+04
# C(county)[T.009]                       5847.5787   2053.897      2.847      0.004    1822.014    9873.144
# C(county)[T.011]                       1.532e+04   1757.845      8.713      0.000    1.19e+04    1.88e+04
# C(county)[T.012]                      -6.751e+04   1.17e+04     -5.759      0.000   -9.05e+04   -4.45e+04
# C(county)[T.013]                       -527.0007   1459.063     -0.361      0.718   -3386.711    2332.709
# C(county)[T.014]                      -4598.0366   8553.016     -0.538      0.591   -2.14e+04    1.22e+04
# C(county)[T.015]                       6722.7491   2275.038      2.955      0.003    2263.756    1.12e+04
# C(county)[T.017]                       2913.8461   1686.959      1.727      0.084    -392.532    6220.225
# C(county)[T.019]                      -1295.2477   1797.913     -0.720      0.471   -4819.092    2228.597
# C(county)[T.021]                       3387.4956   1908.802      1.775      0.076    -353.688    7128.679
# C(county)[T.023]                       8494.9727   2339.616      3.631      0.000    3909.409    1.31e+04
# C(county)[T.025]                       2575.5607   1893.603      1.360      0.174   -1135.833    6286.954
# C(county)[T.027]                       8661.5394   1919.162      4.513      0.000    4900.050    1.24e+04
# C(county)[T.830]                       -2.93e+04   2973.197     -9.855      0.000   -3.51e+04   -2.35e+04
# C(county)[T.840]                       9391.6053   1.48e+04      0.634      0.526   -1.96e+04    3.84e+04
# median_income                          5676.9803    172.412     32.927      0.000    5339.059    6014.901
# pop_density                            6454.8773    197.230     32.728      0.000    6068.314    6841.441
# ==============================================================================
# Omnibus:                     1389.933   Durbin-Watson:                   1.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2636.785
# Skew:                           0.093   Prob(JB):                         0.00
# Kurtosis:                       3.863   Cond. No.                         299.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
#
# Number of observations: 81,291

# %%
df.columns
# Out:
# Index(['GEOID', 'avg_d_kbps_fixed', 'avg_d_kbps_mobile', 'tests_fixed',
#        'tests_mobile', 'NAME', 'population', 'acs_year', 'state', 'county',
#        'tract', 'median_income', 'STUSPS', 'county_name', 'urban_core_type',
#        'primary_ruca_desc', 'primary_dest_code', 'pop_density'],
#       dtype='object')

# %%
# OLS Regression: avg_d_kbps_fixed ~ median_income + urban_core_type
import statsmodels.formula.api as smf
import pandas as pd
from scipy.stats import zscore

# Prepare data - drop missing values and ensure proper types
t = df.copy()
t = t.dropna()

# Ensure numeric columns are float
t["avg_d_kbps_mobile"] = pd.to_numeric(t["avg_d_kbps_mobile"], errors="coerce")
t["median_income"] = pd.to_numeric(t["median_income"], errors="coerce")
t["median_income"] = np.log(t["median_income"])

# Standardize income to Z scores using scipy
t["median_income"] = zscore(t["median_income"], nan_policy="omit")
t["pop_density"] = zscore(pd.to_numeric(t["pop_density"]), nan_policy="omit")

# Drop any rows that became NaN after conversion
t = t.dropna()

model = smf.ols(
    "avg_d_kbps_mobile ~ median_income + pop_density + C(urban_core_type) + C(county)",
    data=t,
).fit(cov_type="HC3")

# Display results
print(model.summary())
print(f"\nNumber of observations: {len(t):,}")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_d_kbps_mobile   R-squared:                       0.248
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     304.7
# Date:                Mon, 08 Dec 2025   Prob (F-statistic):               0.00
# Time:                        18:57:22   Log-Likelihood:            -1.0334e+06
# No. Observations:               81291   AIC:                         2.067e+06
# Df Residuals:                   80976   BIC:                         2.070e+06
# Df Model:                         314
# Covariance Type:                  HC3
# =========================================================================================================
#                                             coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                              1.643e+05   2990.485     54.951      0.000    1.58e+05     1.7e+05
# C(urban_core_type)[T.Micro core]      -5.517e+04    865.469    -63.749      0.000   -5.69e+04   -5.35e+04
# C(urban_core_type)[T.Rural]            -6.74e+04    599.845   -112.361      0.000   -6.86e+04   -6.62e+04
# C(urban_core_type)[T.Small town core] -6.014e+04   1195.479    -50.309      0.000   -6.25e+04   -5.78e+04
# C(county)[T.003]                       -102.7694   3823.834     -0.027      0.979   -7597.347    7391.808
# C(county)[T.005]                      -2.513e+04   3613.699     -6.953      0.000   -3.22e+04    -1.8e+04
# C(county)[T.006]                      -5.448e+04   6099.965     -8.932      0.000   -6.64e+04   -4.25e+04
# C(county)[T.007]                       -410.3544   4594.012     -0.089      0.929   -9414.452    8593.743
